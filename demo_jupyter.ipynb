# %%
import Pkg
# Tell Julia to use the Project.toml and Manifest.toml specified in the directory containing this file
Pkg.activate(@__DIR__ )
# Shouldn't need to instantiate if you build first
# Pkg.instantiate()

# %%
using ExamplePkg

# %%
hello()

# %%
ExamplePkg.goodbye()
